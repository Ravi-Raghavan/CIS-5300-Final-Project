# %% [markdown]
# # Miscellaneous

# %%
import numpy as np
import pandas as pd

# Load test data
test_df = pd.read_csv('../data/test_data.csv')
y_true_test = test_df['label'].values

# Save as .npy file
np.save('ground-truth-test.npy', y_true_test)
